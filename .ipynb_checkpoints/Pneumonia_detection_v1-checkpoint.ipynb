# %% [markdown]
# # Childhood pneumonia detection

# %% [markdown]
# **Basics of Building a Neural Network with Keras:**
# **Basics of Building a Neural Network with Keras:**
# 1. **Import required modules**
#     - **For general neural network**
#         - `from keras import models, layers,optimizers`
#     - **For text:**
#         - `from keras.preprocessing.text import Tokenizer`
#         - `from keras.utils import to_categorical`
#     - **For images:**
#         - `from keras.preprocessing.image import ImageDataGenerator, img_to_array, array_to_img`
#     - **For relocating image files:**
#         - `import os, shutil`
#
#         2. **Decide on a network architecture (have only discussed sequential thus far)**
#     - `model = models.Sequential()`
#
# 3. **Adding layers - specifying layer type, number of neurons, activation functions, and, optionally, the input shape.**
#     - `model.add(layers.Dense(units, activation='relu', input_shape))`
#     - `model.add(layers.Dense(units, activation='relu')`
#     - **3B. Final layer choice:**
#         - Want to have as many neurons as classes you are trying to predict
#         -  Final activation function:
#             - For binary classificaiton, use `activation='sigmoid'`
#             - For multi classificaiton, use `activation='softmax'`
#         - For regression tasks, have a single final neuron.
#
# 5. **Training the model**
#     - `model.fit(X_train, y_train, epochs=20,batch_size=512,validation_data=(x_val,y_val))`
#         - Note: if using images with ImageDataGenerator, use `model.fit_generator()`
#
#     - **batches:**
#         - a set of N samples, processed independently in parallel
#         - a batch determines how many samples are fed through before back-propagation.
#         - model only updates after a batch is complete.
#         - ideally have as large of a batch as your hardware can handle without going out of memory.
#             - larger batches usually run faster than smaller ones for evaluation/prediction.
#     - **epoch:**
#         - arbitrary cutoff / "one pass over the entire dataset", useful for logging and periodic evaluation
#         - when using kera's `model.fit` parameters `validation_data` or `validation_split`, these evaluations run at the end of every epoch.
#         - Within Keras can add callbacksto be run at the end of an epoch. Examples of these are learning rate changes and model checkpointing (saving).
#
#
# 6. **Evaluation / Predictions**
#     - To get predicted results:
#         - `y_hat_test = model.predict(test)`
#     - To get evaluation metrics:
#         - `results_test = model.evaluate(test, label_test)`
#
#
# 7. **Visualization**
#     - **`history =  model.fit()` creates history object with .history attribute.**
#         - `history.history()` returns a dictionary of metrics from each epoch.
#             - `history.history['loss']` and `history.history['acc']`
#
# ### 💡 Data Augmentation (not covered in class)
# - Simplest way to reduce overfitting is to increase the size of the training data.
# - Difficult to do with large datasets, but can be implemented with images as shown below:
# - **For augmenting image data:**
#     - Can alter the images already present in the training data by shifting, shearing, scaling, rotating.<br><br> <img src ="https://www.dropbox.com/s/9i1hl3quwo294jr/data_augmentation_example.png?raw=1" width=300>
#     - This usually provides a big leap in improving the accuracy of the model. It can be considered as a mandatory trick in order to improve our predictions.
#
# - **In Keras:**
#     - `ImageDataGenerator` contains several augmentations available.
#     - Example below:
#
# ```python
# from keras.preprocessing.image import ImageDataGenerator
# datagen = ImageDataGenerator(horizontal flip=True)
# datagen.fit(train)

# %%
# !pip install -U imageio
# !pip install -U scikit-image

# !pip install pillow
# !pip install opencv-contrib-python
# !pip install -U fsds
# !pip install -U tensorflow

# !pip install -U keras
# !pip install -U pandas 
# !pip install -U pandas-profiling

# %conda update matploltib
# %conda update scikit-learn
# !pip install -U matplotlib
# Out:
# Collecting imageio
#   Using cached imageio-2.8.0-py3-none-any.whl (3.3 MB)
# Requirement already satisfied, skipping upgrade: numpy in c:\users\zachmih\anaconda3\lib\site-packages (from imageio) (1.18.3)
# Requirement already satisfied, skipping upgrade: pillow in c:\users\zachmih\anaconda3\lib\site-packages (from imageio) (5.2.0)
# Installing collected packages: imageio
#   Attempting uninstall: imageio
#     Found existing installation: imageio 2.4.1
# ERROR: Cannot uninstall 'imageio'. It is a distutils installed project and thus we cannot accurately determine which files belong to it which would lead to only a partial uninstall.
# Requirement already up-to-date: scikit-image in c:\users\zachmih\anaconda3\lib\site-packages (0.17.2)
# Requirement already satisfied, skipping upgrade: numpy>=1.15.1 in c:\users\zachmih\anaconda3\lib\site-packages (from scikit-image) (1.18.3)
# Requirement already satisfied, skipping upgrade: networkx>=2.0 in c:\users\zachmih\anaconda3\lib\site-packages (from scikit-image) (2.1)
# Requirement already satisfied, skipping upgrade: pillow!=7.1.0,!=7.1.1,>=4.3.0 in c:\users\zachmih\anaconda3\lib\site-packages (from scikit-image) (5.2.0)
# Requirement already satisfied, skipping upgrade: PyWavelets>=1.1.1 in c:\users\zachmih\anaconda3\lib\site-packages (from scikit-image) (1.1.1)
# Requirement already satisfied, skipping upgrade: tifffile>=2019.7.26 in c:\users\zachmih\anaconda3\lib\site-packages (from scikit-image) (2020.6.3)
# Requirement already satisfied, skipping upgrade: matplotlib!=3.0.0,>=2.0.0 in c:\users\zachmih\anaconda3\lib\site-packages (from scikit-image) (3.2.1)
# Requirement already satisfied, skipping upgrade: scipy>=1.0.1 in c:\users\zachmih\anaconda3\lib\site-packages (from scikit-image) (1.1.0)
# Requirement already satisfied, skipping upgrade: imageio>=2.3.0 in c:\users\zachmih\anaconda3\lib\site-packages (from scikit-image) (2.4.1)
# Requirement already satisfied, skipping upgrade: decorator>=4.1.0 in c:\users\zachmih\anaconda3\lib\site-packages (from networkx>=2.0->scikit-image) (4.3.0)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in c:\users\zachmih\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image) (1.0.1)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in c:\users\zachmih\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image) (2.2.0)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in c:\users\zachmih\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image) (0.10.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in c:\users\zachmih\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image) (2.7.3)
# Requirement already satisfied, skipping upgrade: setuptools in c:\users\zachmih\anaconda3\lib\site-packages (from kiwisolver>=1.0.1->matplotlib!=3.0.0,>=2.0.0->scikit-image) (47.1.1)
# Requirement already satisfied, skipping upgrade: six in c:\users\zachmih\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib!=3.0.0,>=2.0.0->scikit-image) (1.15.0)
# Requirement already satisfied: pillow in c:\users\zachmih\anaconda3\lib\site-packages (5.2.0)
# Requirement already satisfied: opencv-contrib-python in c:\users\zachmih\anaconda3\lib\site-packages (4.2.0.34)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\zachmih\anaconda3\lib\site-packages (from opencv-contrib-python) (1.18.3)
# Requirement already up-to-date: fsds in c:\users\zachmih\anaconda3\lib\site-packages (0.2.10)
# Requirement already satisfied, skipping upgrade: ipywidgets in c:\users\zachmih\anaconda3\lib\site-packages (from fsds) (7.4.1)
# Requirement already satisfied, skipping upgrade: cufflinks in c:\users\zachmih\anaconda3\lib\site-packages (from fsds) (0.17.3)
# Requirement already satisfied, skipping upgrade: pandas-profiling in c:\users\zachmih\anaconda3\lib\site-packages (from fsds) (2.3.0)
# Requirement already satisfied, skipping upgrade: wordcloud in c:\users\zachmih\anaconda3\lib\site-packages (from fsds) (1.6.0)
# Requirement already satisfied, skipping upgrade: seaborn in c:\users\zachmih\anaconda3\lib\site-packages (from fsds) (0.9.0)
# Requirement already satisfied, skipping upgrade: tzlocal in c:\users\zachmih\anaconda3\lib\site-packages (from fsds) (2.0.0)
# Requirement already satisfied, skipping upgrade: IPython in c:\users\zachmih\anaconda3\lib\site-packages (from fsds) (6.5.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.18 in c:\users\zachmih\anaconda3\lib\site-packages (from fsds) (1.18.3)
# Requirement already satisfied, skipping upgrade: scikit-learn>=0.23.1 in c:\users\zachmih\anaconda3\lib\site-packages (from fsds) (0.23.1)
# Requirement already satisfied, skipping upgrade: scipy in c:\users\zachmih\anaconda3\lib\site-packages (from fsds) (1.1.0)
# Requirement already satisfied, skipping upgrade: pandas>1.0.0 in c:\users\zachmih\anaconda3\lib\site-packages (from fsds) (1.0.3)
# Requirement already satisfied, skipping upgrade: pyperclip in c:\users\zachmih\anaconda3\lib\site-packages (from fsds) (1.7.0)
# Requirement already satisfied, skipping upgrade: pprint in c:\users\zachmih\anaconda3\lib\site-packages (from fsds) (0.1)
# Requirement already satisfied, skipping upgrade: matplotlib>=3.2.0 in c:\users\zachmih\anaconda3\lib\site-packages (from fsds) (3.2.1)
# Requirement already satisfied, skipping upgrade: missingno in c:\users\zachmih\anaconda3\lib\site-packages (from fsds) (0.4.2)
# Requirement already satisfied, skipping upgrade: nbformat>=4.2.0 in c:\users\zachmih\anaconda3\lib\site-packages (from ipywidgets->fsds) (4.4.0)
# Requirement already satisfied, skipping upgrade: widgetsnbextension~=3.4.0 in c:\users\zachmih\anaconda3\lib\site-packages (from ipywidgets->fsds) (3.4.1)
# Requirement already satisfied, skipping upgrade: ipykernel>=4.5.1 in c:\users\zachmih\anaconda3\lib\site-packages (from ipywidgets->fsds) (4.10.0)
# Requirement already satisfied, skipping upgrade: traitlets>=4.3.1 in c:\users\zachmih\anaconda3\lib\site-packages (from ipywidgets->fsds) (4.3.2)
# Requirement already satisfied, skipping upgrade: colorlover>=0.2.1 in c:\users\zachmih\anaconda3\lib\site-packages (from cufflinks->fsds) (0.3.0)
# Requirement already satisfied, skipping upgrade: six>=1.9.0 in c:\users\zachmih\anaconda3\lib\site-packages (from cufflinks->fsds) (1.15.0)
# Requirement already satisfied, skipping upgrade: setuptools>=34.4.1 in c:\users\zachmih\anaconda3\lib\site-packages (from cufflinks->fsds) (47.1.1)
# Requirement already satisfied, skipping upgrade: plotly>=4.1.1 in c:\users\zachmih\anaconda3\lib\site-packages (from cufflinks->fsds) (4.6.0)
# Requirement already satisfied, skipping upgrade: phik>=0.9.8 in c:\users\zachmih\anaconda3\lib\site-packages (from pandas-profiling->fsds) (0.9.8)
# Requirement already satisfied, skipping upgrade: jinja2>=2.8 in c:\users\zachmih\anaconda3\lib\site-packages (from pandas-profiling->fsds) (2.10)
# Requirement already satisfied, skipping upgrade: confuse>=1.0.0 in c:\users\zachmih\anaconda3\lib\site-packages (from pandas-profiling->fsds) (1.0.0)
# Requirement already satisfied, skipping upgrade: htmlmin>=0.1.12 in c:\users\zachmih\anaconda3\lib\site-packages (from pandas-profiling->fsds) (0.1.12)
# Requirement already satisfied, skipping upgrade: astropy in c:\users\zachmih\anaconda3\lib\site-packages (from pandas-profiling->fsds) (3.0.4)
# Requirement already satisfied, skipping upgrade: pillow in c:\users\zachmih\anaconda3\lib\site-packages (from wordcloud->fsds) (5.2.0)
# Requirement already satisfied, skipping upgrade: pytz in c:\users\zachmih\anaconda3\lib\site-packages (from tzlocal->fsds) (2018.5)
# Requirement already satisfied, skipping upgrade: pygments in c:\users\zachmih\anaconda3\lib\site-packages (from IPython->fsds) (2.2.0)
# Requirement already satisfied, skipping upgrade: prompt-toolkit<2.0.0,>=1.0.15 in c:\users\zachmih\anaconda3\lib\site-packages (from IPython->fsds) (1.0.15)
# Requirement already satisfied, skipping upgrade: jedi>=0.10 in c:\users\zachmih\anaconda3\lib\site-packages (from IPython->fsds) (0.12.1)
# Requirement already satisfied, skipping upgrade: pickleshare in c:\users\zachmih\anaconda3\lib\site-packages (from IPython->fsds) (0.7.4)
# Requirement already satisfied, skipping upgrade: decorator in c:\users\zachmih\anaconda3\lib\site-packages (from IPython->fsds) (4.3.0)
# Requirement already satisfied, skipping upgrade: simplegeneric>0.8 in c:\users\zachmih\anaconda3\lib\site-packages (from IPython->fsds) (0.8.1)
# Requirement already satisfied, skipping upgrade: colorama; sys_platform == "win32" in c:\users\zachmih\anaconda3\lib\site-packages (from IPython->fsds) (0.3.9)
# Requirement already satisfied, skipping upgrade: backcall in c:\users\zachmih\anaconda3\lib\site-packages (from IPython->fsds) (0.1.0)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in c:\users\zachmih\anaconda3\lib\site-packages (from scikit-learn>=0.23.1->fsds) (0.14.1)
# Requirement already satisfied, skipping upgrade: threadpoolctl>=2.0.0 in c:\users\zachmih\anaconda3\lib\site-packages (from scikit-learn>=0.23.1->fsds) (2.1.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.6.1 in c:\users\zachmih\anaconda3\lib\site-packages (from pandas>1.0.0->fsds) (2.7.3)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in c:\users\zachmih\anaconda3\lib\site-packages (from matplotlib>=3.2.0->fsds) (0.10.0)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in c:\users\zachmih\anaconda3\lib\site-packages (from matplotlib>=3.2.0->fsds) (1.0.1)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in c:\users\zachmih\anaconda3\lib\site-packages (from matplotlib>=3.2.0->fsds) (2.2.0)
# Requirement already satisfied, skipping upgrade: jsonschema!=2.5.0,>=2.4 in c:\users\zachmih\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->fsds) (2.6.0)
# Requirement already satisfied, skipping upgrade: ipython-genutils in c:\users\zachmih\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->fsds) (0.2.0)
# Requirement already satisfied, skipping upgrade: jupyter-core in c:\users\zachmih\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->fsds) (4.4.0)
# Requirement already satisfied, skipping upgrade: notebook>=4.4.1 in c:\users\zachmih\anaconda3\lib\site-packages (from widgetsnbextension~=3.4.0->ipywidgets->fsds) (5.6.0)
# Requirement already satisfied, skipping upgrade: jupyter_client in c:\users\zachmih\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->fsds) (5.2.3)
# Requirement already satisfied, skipping upgrade: tornado>=4.0 in c:\users\zachmih\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->fsds) (5.1)
# Requirement already satisfied, skipping upgrade: retrying>=1.3.3 in c:\users\zachmih\anaconda3\lib\site-packages (from plotly>=4.1.1->cufflinks->fsds) (1.3.3)
# Requirement already satisfied, skipping upgrade: pytest-pylint>=0.13.0 in c:\users\zachmih\anaconda3\lib\site-packages (from phik>=0.9.8->pandas-profiling->fsds) (0.14.1)
# Requirement already satisfied, skipping upgrade: numba>=0.38.1 in c:\users\zachmih\anaconda3\lib\site-packages (from phik>=0.9.8->pandas-profiling->fsds) (0.39.0)
# Requirement already satisfied, skipping upgrade: nbconvert>=5.3.1 in c:\users\zachmih\anaconda3\lib\site-packages (from phik>=0.9.8->pandas-profiling->fsds) (5.4.0)
# Requirement already satisfied, skipping upgrade: pytest>=4.0.2 in c:\users\zachmih\anaconda3\lib\site-packages (from phik>=0.9.8->pandas-profiling->fsds) (5.3.2)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=0.23 in c:\users\zachmih\anaconda3\lib\site-packages (from jinja2>=2.8->pandas-profiling->fsds) (1.0)
# Requirement already satisfied, skipping upgrade: pyyaml in c:\users\zachmih\anaconda3\lib\site-packages (from confuse>=1.0.0->pandas-profiling->fsds) (3.13)
# Requirement already satisfied, skipping upgrade: wcwidth in c:\users\zachmih\anaconda3\lib\site-packages (from prompt-toolkit<2.0.0,>=1.0.15->IPython->fsds) (0.1.7)
# Requirement already satisfied, skipping upgrade: parso>=0.3.0 in c:\users\zachmih\anaconda3\lib\site-packages (from jedi>=0.10->IPython->fsds) (0.3.1)
# Requirement already satisfied, skipping upgrade: terminado>=0.8.1 in c:\users\zachmih\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets->fsds) (0.8.1)
# Requirement already satisfied, skipping upgrade: pyzmq>=17 in c:\users\zachmih\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets->fsds) (17.1.2)
# Requirement already satisfied, skipping upgrade: Send2Trash in c:\users\zachmih\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets->fsds) (1.5.0)
# Requirement already satisfied, skipping upgrade: prometheus-client in c:\users\zachmih\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets->fsds) (0.3.1)
# Requirement already satisfied, skipping upgrade: pylint>=1.4.5 in c:\users\zachmih\anaconda3\lib\site-packages (from pytest-pylint>=0.13.0->phik>=0.9.8->pandas-profiling->fsds) (2.1.1)
# Requirement already satisfied, skipping upgrade: llvmlite>=0.24.0dev0 in c:\users\zachmih\anaconda3\lib\site-packages (from numba>=0.38.1->phik>=0.9.8->pandas-profiling->fsds) (0.24.0)
# Requirement already satisfied, skipping upgrade: mistune>=0.8.1 in c:\users\zachmih\anaconda3\lib\site-packages (from nbconvert>=5.3.1->phik>=0.9.8->pandas-profiling->fsds) (0.8.3)
# Requirement already satisfied, skipping upgrade: entrypoints>=0.2.2 in c:\users\zachmih\anaconda3\lib\site-packages (from nbconvert>=5.3.1->phik>=0.9.8->pandas-profiling->fsds) (0.2.3)
# Requirement already satisfied, skipping upgrade: bleach in c:\users\zachmih\anaconda3\lib\site-packages (from nbconvert>=5.3.1->phik>=0.9.8->pandas-profiling->fsds) (2.1.4)
# Requirement already satisfied, skipping upgrade: pandocfilters>=1.4.1 in c:\users\zachmih\anaconda3\lib\site-packages (from nbconvert>=5.3.1->phik>=0.9.8->pandas-profiling->fsds) (1.4.2)
# Requirement already satisfied, skipping upgrade: testpath in c:\users\zachmih\anaconda3\lib\site-packages (from nbconvert>=5.3.1->phik>=0.9.8->pandas-profiling->fsds) (0.3.1)
# Requirement already satisfied, skipping upgrade: defusedxml in c:\users\zachmih\anaconda3\lib\site-packages (from nbconvert>=5.3.1->phik>=0.9.8->pandas-profiling->fsds) (0.5.0)
# Requirement already satisfied, skipping upgrade: py>=1.5.0 in c:\users\zachmih\anaconda3\lib\site-packages (from pytest>=4.0.2->phik>=0.9.8->pandas-profiling->fsds) (1.6.0)
# Requirement already satisfied, skipping upgrade: pluggy<1.0,>=0.12 in c:\users\zachmih\anaconda3\lib\site-packages (from pytest>=4.0.2->phik>=0.9.8->pandas-profiling->fsds) (0.13.1)
# Requirement already satisfied, skipping upgrade: more-itertools>=4.0.0 in c:\users\zachmih\anaconda3\lib\site-packages (from pytest>=4.0.2->phik>=0.9.8->pandas-profiling->fsds) (4.3.0)
# Requirement already satisfied, skipping upgrade: packaging in c:\users\zachmih\anaconda3\lib\site-packages (from pytest>=4.0.2->phik>=0.9.8->pandas-profiling->fsds) (17.1)
# Requirement already satisfied, skipping upgrade: atomicwrites>=1.0; sys_platform == "win32" in c:\users\zachmih\anaconda3\lib\site-packages (from pytest>=4.0.2->phik>=0.9.8->pandas-profiling->fsds) (1.2.1)
# Requirement already satisfied, skipping upgrade: importlib-metadata>=0.12; python_version < "3.8" in c:\users\zachmih\anaconda3\lib\site-packages (from pytest>=4.0.2->phik>=0.9.8->pandas-profiling->fsds) (1.3.0)
# Requirement already satisfied, skipping upgrade: attrs>=17.4.0 in c:\users\zachmih\anaconda3\lib\site-packages (from pytest>=4.0.2->phik>=0.9.8->pandas-profiling->fsds) (18.2.0)
# Requirement already satisfied, skipping upgrade: mccabe in c:\users\zachmih\anaconda3\lib\site-packages (from pylint>=1.4.5->pytest-pylint>=0.13.0->phik>=0.9.8->pandas-profiling->fsds) (0.6.1)
# Requirement already satisfied, skipping upgrade: astroid>=2.0.0 in c:\users\zachmih\anaconda3\lib\site-packages (from pylint>=1.4.5->pytest-pylint>=0.13.0->phik>=0.9.8->pandas-profiling->fsds) (2.0.4)
# Requirement already satisfied, skipping upgrade: isort>=4.2.5 in c:\users\zachmih\anaconda3\lib\site-packages (from pylint>=1.4.5->pytest-pylint>=0.13.0->phik>=0.9.8->pandas-profiling->fsds) (4.3.4)
# Requirement already satisfied, skipping upgrade: html5lib!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8,>=0.99999999pre in c:\users\zachmih\anaconda3\lib\site-packages (from bleach->nbconvert>=5.3.1->phik>=0.9.8->pandas-profiling->fsds) (1.0.1)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in c:\users\zachmih\anaconda3\lib\site-packages (from importlib-metadata>=0.12; python_version < "3.8"->pytest>=4.0.2->phik>=0.9.8->pandas-profiling->fsds) (0.6.0)
# Requirement already satisfied, skipping upgrade: wrapt in c:\users\zachmih\anaconda3\lib\site-packages (from astroid>=2.0.0->pylint>=1.4.5->pytest-pylint>=0.13.0->phik>=0.9.8->pandas-profiling->fsds) (1.10.11)
# Requirement already satisfied, skipping upgrade: lazy-object-proxy in c:\users\zachmih\anaconda3\lib\site-packages (from astroid>=2.0.0->pylint>=1.4.5->pytest-pylint>=0.13.0->phik>=0.9.8->pandas-profiling->fsds) (1.3.1)
# Requirement already satisfied, skipping upgrade: webencodings in c:\users\zachmih\anaconda3\lib\site-packages (from html5lib!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8,>=0.99999999pre->bleach->nbconvert>=5.3.1->phik>=0.9.8->pandas-profiling->fsds) (0.5.1)
# Collecting tensorflow
#   Using cached tensorflow-2.2.0-cp37-cp37m-win_amd64.whl (459.2 MB)
# Collecting astunparse==1.6.3
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting tensorflow-estimator<2.3.0,>=2.2.0
#   Using cached tensorflow_estimator-2.2.0-py2.py3-none-any.whl (454 kB)
# Processing c:\users\zachmih\appdata\local\pip\cache\wheels\b1\c2\ed\d62208260edbd3fa7156545c00ef966f45f2063d0a84f8208a\wrapt-1.12.1-cp37-none-any.whl
# Requirement already satisfied, skipping upgrade: grpcio>=1.8.6 in c:\users\zachmih\anaconda3\lib\site-packages (from tensorflow) (1.20.1)
# Collecting h5py<2.11.0,>=2.10.0
#   Using cached h5py-2.10.0-cp37-cp37m-win_amd64.whl (2.5 MB)
# Requirement already satisfied, skipping upgrade: absl-py>=0.7.0 in c:\users\zachmih\anaconda3\lib\site-packages (from tensorflow) (0.7.1)
# Requirement already satisfied, skipping upgrade: opt-einsum>=2.3.2 in c:\users\zachmih\anaconda3\lib\site-packages (from tensorflow) (3.2.1)
# Requirement already satisfied, skipping upgrade: six>=1.12.0 in c:\users\zachmih\anaconda3\lib\site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied, skipping upgrade: termcolor>=1.1.0 in c:\users\zachmih\anaconda3\lib\site-packages (from tensorflow) (1.1.0)
# Collecting gast==0.3.3
#   Using cached gast-0.3.3-py2.py3-none-any.whl (9.7 kB)
# Collecting tensorboard<2.3.0,>=2.2.0
#   Using cached tensorboard-2.2.2-py3-none-any.whl (3.0 MB)
# Requirement already satisfied, skipping upgrade: google-pasta>=0.1.8 in c:\users\zachmih\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Collecting keras-preprocessing>=1.1.0
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Collecting scipy==1.4.1; python_version >= "3"
#   Using cached scipy-1.4.1-cp37-cp37m-win_amd64.whl (30.9 MB)
# Requirement already satisfied, skipping upgrade: numpy<2.0,>=1.16.0 in c:\users\zachmih\anaconda3\lib\site-packages (from tensorflow) (1.18.3)
# Requirement already satisfied, skipping upgrade: protobuf>=3.8.0 in c:\users\zachmih\anaconda3\lib\site-packages (from tensorflow) (3.12.2)
# Requirement already satisfied, skipping upgrade: wheel>=0.26; python_version >= "3" in c:\users\zachmih\anaconda3\lib\site-packages (from tensorflow) (0.31.1)
# Requirement already satisfied, skipping upgrade: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\zachmih\anaconda3\lib\site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow) (0.4.1)
# Requirement already satisfied, skipping upgrade: werkzeug>=0.11.15 in c:\users\zachmih\anaconda3\lib\site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow) (0.14.1)
# Requirement already satisfied, skipping upgrade: requests<3,>=2.21.0 in c:\users\zachmih\anaconda3\lib\site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow) (2.23.0)
# Requirement already satisfied, skipping upgrade: setuptools>=41.0.0 in c:\users\zachmih\anaconda3\lib\site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow) (47.1.1)
# Requirement already satisfied, skipping upgrade: google-auth<2,>=1.6.3 in c:\users\zachmih\anaconda3\lib\site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow) (1.6.3)
# Requirement already satisfied, skipping upgrade: markdown>=2.6.8 in c:\users\zachmih\anaconda3\lib\site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow) (3.1)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Using cached tensorboard_plugin_wit-1.6.0.post3-py3-none-any.whl (777 kB)
# Requirement already satisfied, skipping upgrade: requests-oauthlib>=0.7.0 in c:\users\zachmih\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow) (1.3.0)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\zachmih\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow) (1.23)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in c:\users\zachmih\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in c:\users\zachmih\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow) (2019.11.28)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in c:\users\zachmih\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow) (2.7)
# Requirement already satisfied, skipping upgrade: rsa>=3.1.4 in c:\users\zachmih\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow) (4.0)
# Requirement already satisfied, skipping upgrade: cachetools>=2.0.0 in c:\users\zachmih\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow) (3.1.0)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in c:\users\zachmih\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow) (0.2.2)
# Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in c:\users\zachmih\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow) (3.1.0)
# Requirement already satisfied, skipping upgrade: pyasn1>=0.1.3 in c:\users\zachmih\anaconda3\lib\site-packages (from rsa>=3.1.4->google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow) (0.4.4)
# Installing collected packages: astunparse, tensorflow-estimator, wrapt, h5py, gast, tensorboard-plugin-wit, tensorboard, keras-preprocessing, scipy, tensorflow
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 1.13.0
#     Uninstalling tensorflow-estimator-1.13.0:
#       Successfully uninstalled tensorflow-estimator-1.13.0
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.10.11
# ERROR: tensorboard 2.2.2 has requirement grpcio>=1.24.3, but you'll have grpcio 1.20.1 which is incompatible.
# ERROR: Cannot uninstall 'wrapt'. It is a distutils installed project and thus we cannot accurately determine which files belong to it which would lead to only a partial uninstall.
# Collecting keras
#   Downloading Keras-2.3.1-py2.py3-none-any.whl (377 kB)
# Requirement already satisfied, skipping upgrade: pyyaml in c:\users\zachmih\anaconda3\lib\site-packages (from keras) (3.13)
# Requirement already satisfied, skipping upgrade: keras-preprocessing>=1.0.5 in c:\users\zachmih\anaconda3\lib\site-packages (from keras) (1.0.9)
# Requirement already satisfied, skipping upgrade: six>=1.9.0 in c:\users\zachmih\anaconda3\lib\site-packages (from keras) (1.15.0)
# Requirement already satisfied, skipping upgrade: h5py in c:\users\zachmih\anaconda3\lib\site-packages (from keras) (2.8.0)
# Requirement already satisfied, skipping upgrade: scipy>=0.14 in c:\users\zachmih\anaconda3\lib\site-packages (from keras) (1.1.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.9.1 in c:\users\zachmih\anaconda3\lib\site-packages (from keras) (1.18.3)
# Requirement already satisfied, skipping upgrade: keras-applications>=1.0.6 in c:\users\zachmih\anaconda3\lib\site-packages (from keras) (1.0.7)
# Installing collected packages: keras
#   Attempting uninstall: keras
#     Found existing installation: Keras 2.2.4
#     Uninstalling Keras-2.2.4:
#       Successfully uninstalled Keras-2.2.4
# Successfully installed keras-2.3.1
# Collecting pandas
#   Downloading pandas-1.0.4-cp37-cp37m-win_amd64.whl (8.7 MB)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in c:\users\zachmih\anaconda3\lib\site-packages (from pandas) (1.18.3)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.6.1 in c:\users\zachmih\anaconda3\lib\site-packages (from pandas) (2.7.3)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in c:\users\zachmih\anaconda3\lib\site-packages (from pandas) (2018.5)
# Requirement already satisfied, skipping upgrade: six>=1.5 in c:\users\zachmih\anaconda3\lib\site-packages (from python-dateutil>=2.6.1->pandas) (1.15.0)
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.0.3
#     Uninstalling pandas-1.0.3:
#       Successfully uninstalled pandas-1.0.3
# Successfully installed pandas-1.0.4
# Collecting pandas-profiling
#   Downloading pandas_profiling-2.8.0-py2.py3-none-any.whl (259 kB)
# Collecting astropy>=4.0
#   Downloading astropy-4.0.1.post1-cp37-cp37m-win_amd64.whl (6.1 MB)
# Requirement already satisfied, skipping upgrade: joblib in c:\users\zachmih\anaconda3\lib\site-packages (from pandas-profiling) (0.14.1)
# Requirement already satisfied, skipping upgrade: htmlmin>=0.1.12 in c:\users\zachmih\anaconda3\lib\site-packages (from pandas-profiling) (0.1.12)
# Collecting phik>=0.9.10
#   Downloading phik-0.10.0-py3-none-any.whl (599 kB)
# Requirement already satisfied, skipping upgrade: requests>=2.23.0 in c:\users\zachmih\anaconda3\lib\site-packages (from pandas-profiling) (2.23.0)
# Collecting tqdm>=4.43.0
#   Downloading tqdm-4.46.1-py2.py3-none-any.whl (63 kB)
# Collecting ipywidgets>=7.5.1
#   Downloading ipywidgets-7.5.1-py2.py3-none-any.whl (121 kB)
# Collecting visions[type_image_path]==0.4.4
#   Downloading visions-0.4.4-py3-none-any.whl (59 kB)
# Requirement already satisfied, skipping upgrade: pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3 in c:\users\zachmih\anaconda3\lib\site-packages (from pandas-profiling) (1.0.4)
# Requirement already satisfied, skipping upgrade: matplotlib>=3.2.0 in c:\users\zachmih\anaconda3\lib\site-packages (from pandas-profiling) (3.2.1)
# Requirement already satisfied, skipping upgrade: confuse>=1.0.0 in c:\users\zachmih\anaconda3\lib\site-packages (from pandas-profiling) (1.0.0)
# Collecting jinja2>=2.11.1
#   Downloading Jinja2-2.11.2-py2.py3-none-any.whl (125 kB)
# Collecting tangled-up-in-unicode>=0.0.6
#   Downloading tangled_up_in_unicode-0.0.6-py3-none-any.whl (3.1 MB)
# Requirement already satisfied, skipping upgrade: missingno>=0.4.2 in c:\users\zachmih\anaconda3\lib\site-packages (from pandas-profiling) (0.4.2)
# Collecting scipy>=1.4.1
#   Using cached scipy-1.4.1-cp37-cp37m-win_amd64.whl (30.9 MB)
# Requirement already satisfied, skipping upgrade: numpy>=1.16.0 in c:\users\zachmih\anaconda3\lib\site-packages (from pandas-profiling) (1.18.3)
# Requirement already satisfied, skipping upgrade: numba>=0.38.1 in c:\users\zachmih\anaconda3\lib\site-packages (from phik>=0.9.10->pandas-profiling) (0.39.0)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in c:\users\zachmih\anaconda3\lib\site-packages (from requests>=2.23.0->pandas-profiling) (3.0.4)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\zachmih\anaconda3\lib\site-packages (from requests>=2.23.0->pandas-profiling) (1.23)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in c:\users\zachmih\anaconda3\lib\site-packages (from requests>=2.23.0->pandas-profiling) (2.7)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in c:\users\zachmih\anaconda3\lib\site-packages (from requests>=2.23.0->pandas-profiling) (2019.11.28)
# Requirement already satisfied, skipping upgrade: ipykernel>=4.5.1 in c:\users\zachmih\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling) (4.10.0)
# Requirement already satisfied, skipping upgrade: traitlets>=4.3.1 in c:\users\zachmih\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling) (4.3.2)
# Requirement already satisfied, skipping upgrade: ipython>=4.0.0; python_version >= "3.3" in c:\users\zachmih\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling) (6.5.0)
# Collecting widgetsnbextension~=3.5.0
#   Downloading widgetsnbextension-3.5.1-py2.py3-none-any.whl (2.2 MB)
# Requirement already satisfied, skipping upgrade: nbformat>=4.2.0 in c:\users\zachmih\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling) (4.4.0)
# Collecting attrs>=19.3.0
#   Downloading attrs-19.3.0-py2.py3-none-any.whl (39 kB)
# Collecting networkx>=2.4
#   Downloading networkx-2.4-py3-none-any.whl (1.6 MB)
# Requirement already satisfied, skipping upgrade: Pillow; extra == "type_image_path" in c:\users\zachmih\anaconda3\lib\site-packages (from visions[type_image_path]==0.4.4->pandas-profiling) (5.2.0)
# Collecting imagehash; extra == "type_image_path"
#   Downloading ImageHash-4.1.0.tar.gz (291 kB)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.6.1 in c:\users\zachmih\anaconda3\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->pandas-profiling) (2.7.3)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in c:\users\zachmih\anaconda3\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->pandas-profiling) (2018.5)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in c:\users\zachmih\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (2.2.0)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in c:\users\zachmih\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.0.1)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in c:\users\zachmih\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (0.10.0)
# Requirement already satisfied, skipping upgrade: pyyaml in c:\users\zachmih\anaconda3\lib\site-packages (from confuse>=1.0.0->pandas-profiling) (3.13)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=0.23 in c:\users\zachmih\anaconda3\lib\site-packages (from jinja2>=2.11.1->pandas-profiling) (1.0)
# Requirement already satisfied, skipping upgrade: seaborn in c:\users\zachmih\anaconda3\lib\site-packages (from missingno>=0.4.2->pandas-profiling) (0.9.0)
# Requirement already satisfied, skipping upgrade: llvmlite>=0.24.0dev0 in c:\users\zachmih\anaconda3\lib\site-packages (from numba>=0.38.1->phik>=0.9.10->pandas-profiling) (0.24.0)
# Requirement already satisfied, skipping upgrade: jupyter_client in c:\users\zachmih\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas-profiling) (5.2.3)
# Requirement already satisfied, skipping upgrade: tornado>=4.0 in c:\users\zachmih\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas-profiling) (5.1)
# Requirement already satisfied, skipping upgrade: six in c:\users\zachmih\anaconda3\lib\site-packages (from traitlets>=4.3.1->ipywidgets>=7.5.1->pandas-profiling) (1.15.0)
# Requirement already satisfied, skipping upgrade: decorator in c:\users\zachmih\anaconda3\lib\site-packages (from traitlets>=4.3.1->ipywidgets>=7.5.1->pandas-profiling) (4.3.0)
# Requirement already satisfied, skipping upgrade: ipython-genutils in c:\users\zachmih\anaconda3\lib\site-packages (from traitlets>=4.3.1->ipywidgets>=7.5.1->pandas-profiling) (0.2.0)
# Requirement already satisfied, skipping upgrade: pygments in c:\users\zachmih\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling) (2.2.0)
# Requirement already satisfied, skipping upgrade: pickleshare in c:\users\zachmih\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling) (0.7.4)
# Requirement already satisfied, skipping upgrade: prompt-toolkit<2.0.0,>=1.0.15 in c:\users\zachmih\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling) (1.0.15)
# Requirement already satisfied, skipping upgrade: jedi>=0.10 in c:\users\zachmih\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling) (0.12.1)
# Requirement already satisfied, skipping upgrade: colorama; sys_platform == "win32" in c:\users\zachmih\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling) (0.3.9)
# Requirement already satisfied, skipping upgrade: setuptools>=18.5 in c:\users\zachmih\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling) (47.1.1)
# Requirement already satisfied, skipping upgrade: simplegeneric>0.8 in c:\users\zachmih\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling) (0.8.1)
# Requirement already satisfied, skipping upgrade: backcall in c:\users\zachmih\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling) (0.1.0)
# Requirement already satisfied, skipping upgrade: notebook>=4.4.1 in c:\users\zachmih\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (5.6.0)
# Requirement already satisfied, skipping upgrade: jupyter-core in c:\users\zachmih\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1->pandas-profiling) (4.4.0)
# Requirement already satisfied, skipping upgrade: jsonschema!=2.5.0,>=2.4 in c:\users\zachmih\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1->pandas-profiling) (2.6.0)
# Requirement already satisfied, skipping upgrade: PyWavelets in c:\users\zachmih\anaconda3\lib\site-packages (from imagehash; extra == "type_image_path"->visions[type_image_path]==0.4.4->pandas-profiling) (1.1.1)
# Requirement already satisfied, skipping upgrade: pyzmq>=13 in c:\users\zachmih\anaconda3\lib\site-packages (from jupyter_client->ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas-profiling) (17.1.2)
# Requirement already satisfied, skipping upgrade: wcwidth in c:\users\zachmih\anaconda3\lib\site-packages (from prompt-toolkit<2.0.0,>=1.0.15->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling) (0.1.7)
# Requirement already satisfied, skipping upgrade: parso>=0.3.0 in c:\users\zachmih\anaconda3\lib\site-packages (from jedi>=0.10->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling) (0.3.1)
# Requirement already satisfied, skipping upgrade: nbconvert in c:\users\zachmih\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (5.4.0)
# Requirement already satisfied, skipping upgrade: prometheus-client in c:\users\zachmih\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (0.3.1)
# Requirement already satisfied, skipping upgrade: Send2Trash in c:\users\zachmih\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (1.5.0)
# Requirement already satisfied, skipping upgrade: terminado>=0.8.1 in c:\users\zachmih\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (0.8.1)
# Requirement already satisfied, skipping upgrade: mistune>=0.8.1 in c:\users\zachmih\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (0.8.3)
# Requirement already satisfied, skipping upgrade: entrypoints>=0.2.2 in c:\users\zachmih\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (0.2.3)
# Requirement already satisfied, skipping upgrade: bleach in c:\users\zachmih\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (2.1.4)
# Requirement already satisfied, skipping upgrade: pandocfilters>=1.4.1 in c:\users\zachmih\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (1.4.2)
# Requirement already satisfied, skipping upgrade: testpath in c:\users\zachmih\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (0.3.1)
# Requirement already satisfied, skipping upgrade: defusedxml in c:\users\zachmih\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (0.5.0)
# Requirement already satisfied, skipping upgrade: html5lib!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8,>=0.99999999pre in c:\users\zachmih\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (1.0.1)
# Requirement already satisfied, skipping upgrade: webencodings in c:\users\zachmih\anaconda3\lib\site-packages (from html5lib!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8,>=0.99999999pre->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (0.5.1)
# Building wheels for collected packages: imagehash
#   Building wheel for imagehash (setup.py): started
#   Building wheel for imagehash (setup.py): finished with status 'done'
#   Created wheel for imagehash: filename=ImageHash-4.1.0-py2.py3-none-any.whl size=291138 sha256=b3fdaea6abec67e2c93c73211cc6d1941a9089f415a8bb2e21145c449ebe39d0
#   Stored in directory: c:\users\zachmih\appdata\local\pip\cache\wheels\16\72\b0\e5be34699908d9ff25dcb3debbb717987b766af61bbddffdfe
# Successfully built imagehash
# Installing collected packages: astropy, scipy, phik, tqdm, widgetsnbextension, ipywidgets, attrs, tangled-up-in-unicode, networkx, imagehash, visions, jinja2, pandas-profiling
#   Attempting uninstall: astropy
#     Found existing installation: astropy 3.0.4
#     Uninstalling astropy-3.0.4:
#       Successfully uninstalled astropy-3.0.4
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.1.0
#     Uninstalling scipy-1.1.0:
#       Successfully uninstalled scipy-1.1.0
#   Attempting uninstall: phik
#     Found existing installation: phik 0.9.8
#     Uninstalling phik-0.9.8:
#       Successfully uninstalled phik-0.9.8
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.26.0
#     Uninstalling tqdm-4.26.0:
#       Successfully uninstalled tqdm-4.26.0
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.4.1
#     Uninstalling widgetsnbextension-3.4.1:
#       Successfully uninstalled widgetsnbextension-3.4.1
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.4.1
#     Uninstalling ipywidgets-7.4.1:
#       Successfully uninstalled ipywidgets-7.4.1
#   Attempting uninstall: attrs
#     Found existing installation: attrs 18.2.0
#     Uninstalling attrs-18.2.0:
#       Successfully uninstalled attrs-18.2.0
#   Attempting uninstall: networkx
#     Found existing installation: networkx 2.1
#     Uninstalling networkx-2.1:
#       Successfully uninstalled networkx-2.1
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 2.10
#     Uninstalling Jinja2-2.10:
#       Successfully uninstalled Jinja2-2.10
#   Attempting uninstall: pandas-profiling
#     Found existing installation: pandas-profiling 2.3.0
#     Uninstalling pandas-profiling-2.3.0:
#       Successfully uninstalled pandas-profiling-2.3.0
# Successfully installed astropy-4.0.1.post1 attrs-19.3.0 imagehash-4.1.0 ipywidgets-7.5.1 jinja2-2.11.2 networkx-2.4 pandas-profiling-2.8.0 phik-0.10.0 scipy-1.4.1 tangled-up-in-unicode-0.0.6 tqdm-4.46.1 visions-0.4.4 widgetsnbextension-3.5.1
# ERROR: twisted 18.7.0 requires PyHamcrest>=1.9.0, which is not installed.
# UsageError: Line magic function `%conda` not found.

# %%
# !pip install -U fsds_100719
from fsds_100719.imports import *
# Out:
# fsds_1007219  v0.7.22 loaded.  Read the docs: https://fsds.readthedocs.io/en/latest/
# <style  type="text/css" >
# </style><table id="T_ea548b0a_ab9f_11ea_a402_5800e3d0a9a8" ><caption>Loaded Packages and Handles</caption><thead>    <tr>        <th class="col_heading level0 col0" >Handle</th>        <th class="col_heading level0 col1" >Package</th>        <th class="col_heading level0 col2" >Description</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_ea548b0a_ab9f_11ea_a402_5800e3d0a9a8row0_col0" class="data row0 col0" >dp</td>
#                         <td id="T_ea548b0a_ab9f_11ea_a402_5800e3d0a9a8row0_col1" class="data row0 col1" >IPython.display</td>
#                         <td id="T_ea548b0a_ab9f_11ea_a402_5800e3d0a9a8row0_col2" class="data row0 col2" >Display modules with helpful display and clearing commands.</td>
#             </tr>
#             <tr>
#                                 <td id="T_ea548b0a_ab9f_11ea_a402_5800e3d0a9a8row1_col0" class="data row1 col0" >fs</td>
#                         <td id="T_ea548b0a_ab9f_11ea_a402_5800e3d0a9a8row1_col1" class="data row1 col1" >fsds_100719</td>
#                         <td id="T_ea548b0a_ab9f_11ea_a402_5800e3d0a9a8row1_col2" class="data row1 col2" >Custom data science bootcamp student package</td>
#             </tr>
#             <tr>
#                                 <td id="T_ea548b0a_ab9f_11ea_a402_5800e3d0a9a8row2_col0" class="data row2 col0" >mpl</td>
#                         <td id="T_ea548b0a_ab9f_11ea_a402_5800e3d0a9a8row2_col1" class="data row2 col1" >matplotlib</td>
#                         <td id="T_ea548b0a_ab9f_11ea_a402_5800e3d0a9a8row2_col2" class="data row2 col2" >Matplotlib's base OOP module with formatting artists</td>
#             </tr>
#             <tr>
#                                 <td id="T_ea548b0a_ab9f_11ea_a402_5800e3d0a9a8row3_col0" class="data row3 col0" >plt</td>
#                         <td id="T_ea548b0a_ab9f_11ea_a402_5800e3d0a9a8row3_col1" class="data row3 col1" >matplotlib.pyplot</td>
#                         <td id="T_ea548b0a_ab9f_11ea_a402_5800e3d0a9a8row3_col2" class="data row3 col2" >Matplotlib's matlab-like plotting module</td>
#             </tr>
#             <tr>
#                                 <td id="T_ea548b0a_ab9f_11ea_a402_5800e3d0a9a8row4_col0" class="data row4 col0" >np</td>
#                         <td id="T_ea548b0a_ab9f_11ea_a402_5800e3d0a9a8row4_col1" class="data row4 col1" >numpy</td>
#                         <td id="T_ea548b0a_ab9f_11ea_a402_5800e3d0a9a8row4_col2" class="data row4 col2" >scientific computing with Python</td>
#             </tr>
#             <tr>
#                                 <td id="T_ea548b0a_ab9f_11ea_a402_5800e3d0a9a8row5_col0" class="data row5 col0" >pd</td>
#                         <td id="T_ea548b0a_ab9f_11ea_a402_5800e3d0a9a8row5_col1" class="data row5 col1" >pandas</td>
#                         <td id="T_ea548b0a_ab9f_11ea_a402_5800e3d0a9a8row5_col2" class="data row5 col2" >High performance data structures and tools</td>
#             </tr>
#             <tr>
#                                 <td id="T_ea548b0a_ab9f_11ea_a402_5800e3d0a9a8row6_col0" class="data row6 col0" >sns</td>
#                         <td id="T_ea548b0a_ab9f_11ea_a402_5800e3d0a9a8row6_col1" class="data row6 col1" >seaborn</td>
#                         <td id="T_ea548b0a_ab9f_11ea_a402_5800e3d0a9a8row6_col2" class="data row6 col2" >High-level data visualization library based on matplotlib</td>
#             </tr>
#     </tbody></table>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# [i] Pandas .iplot() method activated.

# %%
from PIL import Image
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.utils import to_categorical
from imageio import imread

from skimage.transform import resize
import cv2
from tqdm import tqdm
# Out:
# Using TensorFlow backend.
# C:\Users\zachmih\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning:
#
# Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#
# C:\Users\zachmih\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning:
#
# Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#
# C:\Users\zachmih\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning:
#
# Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#
# C:\Users\zachmih\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:529: FutureWarning:
#
# Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#
# C:\Users\zachmih\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:530: FutureWarning:
#
# Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#
# C:\Users\zachmih\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:535: FutureWarning:
#
# Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.

# %%
#import os,glob
#print(os.path.abspath(os.curdir))
# Out:
# C:\Users\zachmih\Documents\2020 FlatIron School\Proj4-image-classification\pneumonia-detection

# %%
# change dataset_folder to match where you stored the files
dataset_folder = "chest_xray"

# %%
base_folder = dataset_folder
base_folder
# Out:
# 'chest_xray'

# %%
import shutil,glob
# ## DOG VS CAT
train_base_dir = base_folder+'training_set/'
test_base_dir =base_folder+'test_set/' 

train_dogs = train_base_dir+'dogs/'
train_cats = train_base_dir+'cats/'

test_dogs = test_base_dir+'dogs/'
test_cats = test_base_dir+'cats/'


dog_train_files = glob.glob(train_dogs+'*.jpg')
cat_train_files = glob.glob(train_cats+'*.jpg')
all_train_files = [*dog_train_files,*cat_train_files]

dog_test_files = glob.glob(test_dogs+'*.jpg')
cat_test_files = glob.glob(test_cats+'*.jpg')
all_test_files = [*dog_test_files,*cat_test_files]

# print(len(img_filenames))
# img_filenames[:10]

all_filename_vars = [dog_train_files, cat_train_files,
                                             dog_test_files,cat_test_files]
